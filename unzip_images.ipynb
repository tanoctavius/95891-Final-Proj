# %% [markdown]
# ONLY GWEN CAN USE!!! DO NOT TOUCH!!!

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
import zipfile

zip_in = "/content/drive/MyDrive/AI final/cleaned data/images_9653.zip"
zip_out = "/content/drive/MyDrive/AI final/cleaned data/images_9653"

with zipfile.ZipFile(zip_in, 'r') as zip_ref:
    zip_ref.extractall(zip_out)
